# %%
import numpy as np
from keras.models import Sequential
from keras.layers import SimpleRNN, Dense, Embedding
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical

# %%
# Generating some example sequential data
sentences = ['I love learning','I love python','I hate school',
             'Recurrent Neural Networks are powerful']

# %%
# Tokenizing the words
tokenizer = Tokenizer()
tokenizer.fit_on_texts(sentences)
total_words = len(tokenizer.word_index) + 1

# %%
# Creating input sequences and their corresponding next words
input_sequences = []
for sentence in sentences:
    tokenized_sentence = tokenizer.texts_to_sequences([sentence])[0]
    for i in range(1, len(tokenized_sentence)):
        n_gram_sequence = tokenized_sentence[:i+1]
        input_sequences.append(n_gram_sequence)

# %%
# Padding sequences for consistent input size
max_sequence_length = max([len(seq) for seq in input_sequences])
input_sequences = pad_sequences(input_sequences, maxlen=max_sequence_length, padding='pre')

# %%
# Creating input and output data
X, y = input_sequences[:, :-1], input_sequences[:, -1]
y = to_categorical(y, num_classes=total_words)

# %%
# Building a simple RNN model
model = Sequential()
model.add(Embedding(input_dim=total_words, output_dim=50, input_length=max_sequence_length-1))
model.add(SimpleRNN(100, return_sequences=True))
model.add(SimpleRNN(100))
model.add(Dense(total_words, activation='softmax'))

# %%
# Compiling the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Training the model
model.fit(X, y, epochs=50, verbose=2)
# Out:
# Epoch 1/50
# 1/1 - 2s - loss: 2.5081 - accuracy: 0.1000 - 2s/epoch - 2s/step
# Epoch 2/50
# 1/1 - 0s - loss: 2.4190 - accuracy: 0.3000 - 15ms/epoch - 15ms/step
# Epoch 3/50
# 1/1 - 0s - loss: 2.3361 - accuracy: 0.3000 - 12ms/epoch - 12ms/step
# Epoch 4/50
# 1/1 - 0s - loss: 2.2553 - accuracy: 0.3000 - 14ms/epoch - 14ms/step
# Epoch 5/50
# 1/1 - 0s - loss: 2.1743 - accuracy: 0.3000 - 15ms/epoch - 15ms/step
# Epoch 6/50
# 1/1 - 0s - loss: 2.0920 - accuracy: 0.3000 - 14ms/epoch - 14ms/step
# Epoch 7/50
# 1/1 - 0s - loss: 2.0086 - accuracy: 0.4000 - 16ms/epoch - 16ms/step
# Epoch 8/50
# 1/1 - 0s - loss: 1.9247 - accuracy: 0.4000 - 11ms/epoch - 11ms/step
# Epoch 9/50
# 1/1 - 0s - loss: 1.8409 - accuracy: 0.4000 - 15ms/epoch - 15ms/step
# Epoch 10/50
# 1/1 - 0s - loss: 1.7569 - accuracy: 0.4000 - 12ms/epoch - 12ms/step
# Epoch 11/50
# 1/1 - 0s - loss: 1.6721 - accuracy: 0.4000 - 14ms/epoch - 14ms/step
# Epoch 12/50
# 1/1 - 0s - loss: 1.5869 - accuracy: 0.4000 - 11ms/epoch - 11ms/step
# Epoch 13/50
# 1/1 - 0s - loss: 1.5043 - accuracy: 0.5000 - 11ms/epoch - 11ms/step
# Epoch 14/50
# 1/1 - 0s - loss: 1.4285 - accuracy: 0.5000 - 12ms/epoch - 12ms/step
# Epoch 15/50
# 1/1 - 0s - loss: 1.3623 - accuracy: 0.7000 - 12ms/epoch - 12ms/step
# Epoch 16/50
# 1/1 - 0s - loss: 1.3052 - accuracy: 0.7000 - 12ms/epoch - 12ms/step
# Epoch 17/50
# 1/1 - 0s - loss: 1.2538 - accuracy: 0.7000 - 15ms/epoch - 15ms/step
# Epoch 18/50
# 1/1 - 0s - loss: 1.2052 - accuracy: 0.7000 - 13ms/epoch - 13ms/step
# Epoch 19/50
# 1/1 - 0s - loss: 1.1586 - accuracy: 0.7000 - 13ms/epoch - 13ms/step
# Epoch 20/50
# 1/1 - 0s - loss: 1.1148 - accuracy: 0.6000 - 14ms/epoch - 14ms/step
# Epoch 21/50
# 1/1 - 0s - loss: 1.0752 - accuracy: 0.6000 - 14ms/epoch - 14ms/step
# Epoch 22/50
# 1/1 - 0s - loss: 1.0395 - accuracy: 0.6000 - 16ms/epoch - 16ms/step
# Epoch 23/50
# 1/1 - 0s - loss: 1.0056 - accuracy: 0.7000 - 12ms/epoch - 12ms/step
# Epoch 24/50
# 1/1 - 0s - loss: 0.9722 - accuracy: 0.7000 - 13ms/epoch - 13ms/step
# Epoch 25/50
# 1/1 - 0s - loss: 0.9397 - accuracy: 0.7000 - 14ms/epoch - 14ms/step
# Epoch 26/50
# 1/1 - 0s - loss: 0.9089 - accuracy: 0.7000 - 13ms/epoch - 13ms/step
# Epoch 27/50
# 1/1 - 0s - loss: 0.8801 - accuracy: 0.7000 - 13ms/epoch - 13ms/step
# Epoch 28/50
# 1/1 - 0s - loss: 0.8522 - accuracy: 0.7000 - 11ms/epoch - 11ms/step
# Epoch 29/50
# 1/1 - 0s - loss: 0.8247 - accuracy: 0.7000 - 14ms/epoch - 14ms/step
# Epoch 30/50
# 1/1 - 0s - loss: 0.7982 - accuracy: 0.7000 - 11ms/epoch - 11ms/step
# Epoch 31/50
# 1/1 - 0s - loss: 0.7733 - accuracy: 0.7000 - 14ms/epoch - 14ms/step
# Epoch 32/50
# 1/1 - 0s - loss: 0.7504 - accuracy: 0.7000 - 14ms/epoch - 14ms/step
# Epoch 33/50
# 1/1 - 0s - loss: 0.7289 - accuracy: 0.7000 - 15ms/epoch - 15ms/step
# Epoch 34/50
# 1/1 - 0s - loss: 0.7086 - accuracy: 0.7000 - 15ms/epoch - 15ms/step
# Epoch 35/50
# 1/1 - 0s - loss: 0.6893 - accuracy: 0.7000 - 15ms/epoch - 15ms/step
# Epoch 36/50
# 1/1 - 0s - loss: 0.6712 - accuracy: 0.8000 - 14ms/epoch - 14ms/step
# Epoch 37/50
# 1/1 - 0s - loss: 0.6541 - accuracy: 0.8000 - 14ms/epoch - 14ms/step
# Epoch 38/50
# 1/1 - 0s - loss: 0.6379 - accuracy: 0.8000 - 14ms/epoch - 14ms/step
# Epoch 39/50
# 1/1 - 0s - loss: 0.6223 - accuracy: 0.8000 - 22ms/epoch - 22ms/step
# Epoch 40/50
# 1/1 - 0s - loss: 0.6072 - accuracy: 0.8000 - 15ms/epoch - 15ms/step
# Epoch 41/50
# 1/1 - 0s - loss: 0.5927 - accuracy: 0.8000 - 16ms/epoch - 16ms/step
# Epoch 42/50
# 1/1 - 0s - loss: 0.5786 - accuracy: 0.8000 - 12ms/epoch - 12ms/step
# Epoch 43/50
# 1/1 - 0s - loss: 0.5646 - accuracy: 0.8000 - 13ms/epoch - 13ms/step
# Epoch 44/50
# 1/1 - 0s - loss: 0.5509 - accuracy: 0.8000 - 13ms/epoch - 13ms/step
# Epoch 45/50
# 1/1 - 0s - loss: 0.5374 - accuracy: 0.8000 - 13ms/epoch - 13ms/step
# Epoch 46/50
# 1/1 - 0s - loss: 0.5242 - accuracy: 0.8000 - 15ms/epoch - 15ms/step
# Epoch 47/50
# 1/1 - 0s - loss: 0.5113 - accuracy: 0.8000 - 17ms/epoch - 17ms/step
# Epoch 48/50
# 1/1 - 0s - loss: 0.4987 - accuracy: 0.8000 - 12ms/epoch - 12ms/step
# Epoch 49/50
# 1/1 - 0s - loss: 0.4865 - accuracy: 0.8000 - 21ms/epoch - 21ms/step
# Epoch 50/50
# 1/1 - 0s - loss: 0.4747 - accuracy: 0.8000 - 12ms/epoch - 12ms/step

# %%
# Generating text using the trained model
seed_text = input("Enter the starting word: ")
next_words = int(input("Enter how many words to predict: "))

for _ in range(next_words):
    tokenized_seed = tokenizer.texts_to_sequences([seed_text])[0]
    tokenized_seed = pad_sequences([tokenized_seed], maxlen=max_sequence_length-1, padding='pre')
    predicted_word_index = np.argmax(model.predict(tokenized_seed), axis=-1)
    predicted_word = tokenizer.index_word[predicted_word_index[0]]
    seed_text += " " + predicted_word
    print(seed_text)
# Out:
# Enter the starting word: i
# Enter how many words to predict: 1
# 1/1 [==============================] - 0s 291ms/step
# i love
